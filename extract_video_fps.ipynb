# %% [markdown]
# # Extract Video FPS from YouTube URLs
#
# This notebook processes JSON files from the media-info directory, extracts YouTube URLs,
# gets the FPS of each video, and saves the FPS back to the JSON files.

# %%
import os
import json
import yt_dlp
from pathlib import Path
from tqdm import tqdm
import time
import logging

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
# Configuration
MEDIA_INFO_DIR = r"frame-ui\public\media-info-aic25-b1\media-info"
OUTPUT_LOG_FILE = "fps_extraction_log.txt"
ERROR_LOG_FILE = "fps_extraction_errors.txt"

# Verify directory exists
if not os.path.exists(MEDIA_INFO_DIR):
    print(f"Directory not found: {MEDIA_INFO_DIR}")
    print("Please check the path and make sure it exists.")
else:
    print(f"Media info directory found: {MEDIA_INFO_DIR}")
    json_files = [f for f in os.listdir(MEDIA_INFO_DIR) if f.endswith('.json')]
    print(f"Found {len(json_files)} JSON files to process")
# Out:
# Media info directory found: frame-ui\public\media-info-aic25-b1\media-info
# Found 873 JSON files to process

# %%
def get_video_fps(youtube_url, max_retries=3):
    """
    Extract FPS from YouTube video URL using yt-dlp
    
    Args:
        youtube_url (str): YouTube video URL
        max_retries (int): Maximum number of retry attempts
    
    Returns:
        float: FPS value or None if extraction fails
    """
    ydl_opts = {
        'quiet': True,
        'no_warnings': True,
        'extractaudio': False,
        'format': 'best[height<=360]',  # Get reasonable quality to avoid rate limits
    }
    
    for attempt in range(max_retries):
        try:
            with yt_dlp.YoutubeDL(ydl_opts) as ydl:
                info = ydl.extract_info(youtube_url, download=False)
                fps = info.get('fps')
                
                if fps is None:
                    # Try to get fps from formats
                    formats = info.get('formats', [])
                    for format_info in formats:
                        if format_info.get('fps'):
                            fps = format_info['fps']
                            break
                
                if fps:
                    logger.info(f"Successfully extracted FPS: {fps} from {youtube_url}")
                    return fps
                else:
                    logger.warning(f"No FPS information found for {youtube_url}")
                    return None
                    
        except Exception as e:
            logger.error(f"Attempt {attempt + 1} failed for {youtube_url}: {str(e)}")
            if attempt < max_retries - 1:
                time.sleep(2 ** attempt)  # Exponential backoff
            else:
                logger.error(f"All attempts failed for {youtube_url}")
                return None
    
    return None

# %%
def process_json_file(filepath):
    """
    Process a single JSON file to extract and add FPS information
    
    Args:
        filepath (str): Path to the JSON file
    
    Returns:
        tuple: (success: bool, message: str)
    """
    try:
        # Read JSON file
        with open(filepath, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        # Check if FPS already exists
        if 'fps' in data and data['fps'] is not None:
            return True, f"FPS already exists: {data['fps']}"
        
        # Get watch_url
        watch_url = data.get('watch_url')
        if not watch_url:
            return False, "No watch_url found in JSON"
        
        # Extract FPS
        fps = get_video_fps(watch_url)
        
        if fps is not None:
            # Add FPS to data
            data['fps'] = fps
            
            # Write back to file
            with open(filepath, 'w', encoding='utf-8') as f:
                json.dump(data, f, ensure_ascii=False, indent=4)
            
            return True, f"Successfully added FPS: {fps}"
        else:
            return False, "Failed to extract FPS"
            
    except Exception as e:
        return False, f"Error processing file: {str(e)}"

# %%
# Main processing loop
def process_all_files():
    """
    Process all JSON files in the media-info directory
    """
    json_files = [f for f in os.listdir(MEDIA_INFO_DIR) if f.endswith('.json')]
    
    success_count = 0
    error_count = 0
    already_processed_count = 0
    
    # Create log files
    with open(OUTPUT_LOG_FILE, 'w', encoding='utf-8') as log_f, \
         open(ERROR_LOG_FILE, 'w', encoding='utf-8') as error_f:
        
        log_f.write(f"FPS Extraction Log - Started processing {len(json_files)} files\n")
        log_f.write("=" * 60 + "\n")
        
        error_f.write(f"FPS Extraction Errors - Processing {len(json_files)} files\n")
        error_f.write("=" * 60 + "\n")
        
        # Process each file with progress bar
        for filename in tqdm(json_files, desc="Processing JSON files"):
            filepath = os.path.join(MEDIA_INFO_DIR, filename)
            
            success, message = process_json_file(filepath)
            
            if success:
                if "already exists" in message:
                    already_processed_count += 1
                else:
                    success_count += 1
                log_f.write(f"✓ {filename}: {message}\n")
            else:
                error_count += 1
                error_f.write(f"✗ {filename}: {message}\n")
            
            # Flush logs periodically
            if (success_count + error_count + already_processed_count) % 10 == 0:
                log_f.flush()
                error_f.flush()
            
            # Add small delay to avoid rate limiting
            time.sleep(0.5)
    
    # Summary
    total_processed = success_count + error_count + already_processed_count
    print(f"\n" + "=" * 60)
    print(f"PROCESSING COMPLETE")
    print(f"=" * 60)
    print(f"Total files: {len(json_files)}")
    print(f"Successfully processed: {success_count}")
    print(f"Already had FPS: {already_processed_count}")
    print(f"Errors: {error_count}")
    print(f"\nLogs saved to:")
    print(f"- Success log: {OUTPUT_LOG_FILE}")
    print(f"- Error log: {ERROR_LOG_FILE}")
    
    return success_count, error_count, already_processed_count

# %%
# Test with a single file first
def test_single_file():
    """
    Test the processing with a single file
    """
    json_files = [f for f in os.listdir(MEDIA_INFO_DIR) if f.endswith('.json')]
    if not json_files:
        print("No JSON files found!")
        return
    
    test_file = json_files[0]
    filepath = os.path.join(MEDIA_INFO_DIR, test_file)
    
    print(f"Testing with file: {test_file}")
    
    # Read and display current content
    with open(filepath, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    print(f"Current watch_url: {data.get('watch_url')}")
    print(f"Current fps: {data.get('fps', 'Not set')}")
    
    success, message = process_json_file(filepath)
    print(f"Result: {message}")
    
    # Read updated content
    with open(filepath, 'r', encoding='utf-8') as f:
        updated_data = json.load(f)
    
    print(f"Updated fps: {updated_data.get('fps', 'Still not set')}")

# Uncomment the next line to test with a single file first
# test_single_file()

# %%
test_single_file()
# Out:
# Testing with file: L21_V001.json
# Current watch_url: https://youtube.com/watch?v=Rzpw5WR7nAY
# Current fps: Not set
# INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=Rzpw5WR7nAY
# Result: Successfully added FPS: 30
# Updated fps: 30

# %%
process_all_files()
# Out:
# Processing JSON files:  18%|█▊        | 157/873 [01:25<06:22,  1.87it/s]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=4FCtYRiLuho
# Processing JSON files:  18%|█▊        | 158/873 [02:05<2:29:21, 12.53s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=qFZv_xplTlo
# Processing JSON files:  18%|█▊        | 159/873 [02:37<3:36:29, 18.19s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=hgH4k9QFoqY
# Processing JSON files:  18%|█▊        | 160/873 [03:11<4:35:04, 23.15s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=aFxEctSNt6A
# Processing JSON files:  18%|█▊        | 161/873 [03:47<5:19:32, 26.93s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=DGGWhygiKfM
# Processing JSON files:  19%|█▊        | 162/873 [04:30<6:14:09, 31.57s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=zT5rGIkxcqU
# Processing JSON files:  19%|█▊        | 163/873 [05:11<6:49:09, 34.58s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Xwd7sLbjvO4
# Processing JSON files:  19%|█▉        | 164/873 [05:55<7:22:11, 37.42s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=VXCHMOWZtPA
# Processing JSON files:  19%|█▉        | 165/873 [06:38<7:39:30, 38.94s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=C0R9jLrZWPI
# Processing JSON files:  19%|█▉        | 166/873 [07:27<8:14:47, 41.99s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=wpYCa-4aPsE
# Processing JSON files:  19%|█▉        | 167/873 [08:09<8:14:03, 41.99s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=s-Q__1F3K20
# Processing JSON files:  19%|█▉        | 168/873 [08:49<8:08:27, 41.57s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Wqvu09VA6PM
# Processing JSON files:  19%|█▉        | 169/873 [09:38<8:33:47, 43.79s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=FPHW0CAzDHk
# Processing JSON files:  19%|█▉        | 170/873 [10:13<8:01:01, 41.06s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=meQWOeObSHI
# Processing JSON files:  20%|█▉        | 171/873 [11:10<8:55:45, 45.79s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=SXxlU4-8kgw
# Processing JSON files:  20%|█▉        | 172/873 [11:52<8:43:36, 44.82s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=2tpn2LCjDfE
# Processing JSON files:  20%|█▉        | 173/873 [12:30<8:17:16, 42.62s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=y8LeadtZo00
# Processing JSON files:  20%|█▉        | 174/873 [13:08<8:01:57, 41.37s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=1U4dAptxS_0
# Processing JSON files:  20%|██        | 175/873 [13:36<7:12:14, 37.15s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=SippjxdM0wc
# Processing JSON files:  20%|██        | 176/873 [14:02<6:34:32, 33.96s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=JxUA0S-gy7s
# Processing JSON files:  20%|██        | 177/873 [14:26<5:58:54, 30.94s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=u1fz8Yrkl9M
# Processing JSON files:  20%|██        | 178/873 [14:48<5:27:10, 28.25s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=m3ttOhWdj54
# Processing JSON files:  21%|██        | 179/873 [15:06<4:52:40, 25.30s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=r7lvq-F-9VA
# Processing JSON files:  21%|██        | 180/873 [15:29<4:41:45, 24.39s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=9fh-11ybIZk
# Processing JSON files:  21%|██        | 181/873 [15:52<4:38:20, 24.13s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=0yyxartcZ1k
# Processing JSON files:  21%|██        | 182/873 [16:11<4:20:02, 22.58s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=hKCo1ZJA0ME
# Processing JSON files:  21%|██        | 183/873 [16:19<3:28:48, 18.16s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=kuRYuggWUeQ
# Processing JSON files:  21%|██        | 184/873 [16:27<2:53:24, 15.10s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=zXA6EgYmSik
# Processing JSON files:  21%|██        | 185/873 [16:35<2:30:14, 13.10s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=Wa_-aUgd_uQ
# Processing JSON files:  21%|██▏       | 186/873 [16:44<2:15:11, 11.81s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=cZ4l81imqT8
# Processing JSON files:  21%|██▏       | 187/873 [16:56<2:15:35, 11.86s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=IocW0-AgoXQ
# Processing JSON files:  22%|██▏       | 188/873 [17:02<1:54:34, 10.04s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=EY-pV7I1umo
# Processing JSON files:  22%|██▏       | 189/873 [17:08<1:40:38,  8.83s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ntFvvHK594A
# Processing JSON files:  22%|██▏       | 190/873 [17:14<1:29:07,  7.83s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Jt-tIBBhjIA
# Processing JSON files:  22%|██▏       | 191/873 [17:19<1:20:41,  7.10s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=SNccx2GIjAg
# Processing JSON files:  22%|██▏       | 192/873 [17:25<1:16:39,  6.75s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=TLeKwGuiJYY
# Processing JSON files:  22%|██▏       | 193/873 [17:31<1:13:00,  6.44s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=0DeLbMiad3I
# Processing JSON files:  22%|██▏       | 194/873 [17:36<1:08:43,  6.07s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=aQ9UTJnJYdI
# Processing JSON files:  22%|██▏       | 195/873 [17:41<1:06:17,  5.87s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=EekSMrbu2HI
# Processing JSON files:  22%|██▏       | 196/873 [17:48<1:10:10,  6.22s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=rwEXSZ2hRp8
# Processing JSON files:  23%|██▎       | 197/873 [17:56<1:14:31,  6.61s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=1EUKmtBmsCA
# Processing JSON files:  23%|██▎       | 198/873 [18:02<1:12:42,  6.46s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=XQiNoaKMhIQ
# Processing JSON files:  23%|██▎       | 199/873 [18:10<1:16:47,  6.84s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=0gonpkGhDvE
# Processing JSON files:  23%|██▎       | 200/873 [18:16<1:16:12,  6.79s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=irniiF5WuNk
# Processing JSON files:  23%|██▎       | 201/873 [18:22<1:12:38,  6.49s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=3YbEA4ZPn84
# Processing JSON files:  23%|██▎       | 202/873 [18:28<1:09:55,  6.25s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=G05S9VA2TAY
# Processing JSON files:  23%|██▎       | 203/873 [18:34<1:08:39,  6.15s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=StoPvqRURtE
# Processing JSON files:  23%|██▎       | 204/873 [18:39<1:04:16,  5.76s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=KTncCCthOwc
# Processing JSON files:  23%|██▎       | 205/873 [18:46<1:10:02,  6.29s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=ZbJW064Mj8I
# Processing JSON files:  24%|██▎       | 206/873 [18:52<1:09:31,  6.25s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=eaCVBZaxYbc
# Processing JSON files:  24%|██▎       | 207/873 [18:58<1:08:43,  6.19s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=oQAGptD8wWw
# Processing JSON files:  24%|██▍       | 208/873 [19:05<1:09:17,  6.25s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ZZ0lI9P21Mg
# Processing JSON files:  24%|██▍       | 209/873 [19:13<1:15:38,  6.84s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=cejl8cXtKn4
# Processing JSON files:  24%|██▍       | 210/873 [19:20<1:16:16,  6.90s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=aVhqP2rZ3FM
# Processing JSON files:  24%|██▍       | 211/873 [19:26<1:13:57,  6.70s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=7TRzu2iozPk
# Processing JSON files:  24%|██▍       | 212/873 [19:33<1:13:27,  6.67s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=J5dPahxmjik
# Processing JSON files:  24%|██▍       | 213/873 [19:39<1:11:00,  6.45s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=tQnZVSoA48I
# Processing JSON files:  25%|██▍       | 214/873 [19:43<1:04:01,  5.83s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=moQSm-IwjNc
# Processing JSON files:  25%|██▍       | 215/873 [19:48<1:00:29,  5.52s/it]INFO:__main__:Successfully extracted FPS: 30 from https://youtube.com/watch?v=zDv8FJkq7Oc
# Processing JSON files:  25%|██▍       | 216/873 [19:53<1:00:00,  5.48s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=mVf8qMaNHJM
# Processing JSON files:  25%|██▍       | 217/873 [19:59<1:00:46,  5.56s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=DfLO8m0MHtM
# Processing JSON files:  25%|██▍       | 218/873 [20:04<59:47,  5.48s/it]  INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=iIIH4h5U4ck
# Processing JSON files:  25%|██▌       | 219/873 [20:11<1:03:37,  5.84s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=IELN5vkpRnU
# Processing JSON files:  25%|██▌       | 220/873 [20:15<59:05,  5.43s/it]  INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=170XSKqT6Ss
# Processing JSON files:  25%|██▌       | 221/873 [20:20<57:38,  5.31s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=UDZuHAgPuFI
# Processing JSON files:  25%|██▌       | 222/873 [20:27<1:01:12,  5.64s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=bsXAWz6L0Po
# Processing JSON files:  26%|██▌       | 223/873 [20:32<1:00:48,  5.61s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ms7LCwTThD4
# Processing JSON files:  26%|██▌       | 224/873 [20:37<57:50,  5.35s/it]  INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=67RaoFSFhNs
# Processing JSON files:  26%|██▌       | 225/873 [20:44<1:01:24,  5.69s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=q583NiybXOs
# Processing JSON files:  26%|██▌       | 226/873 [20:50<1:05:11,  6.05s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Rq8nxWZQZyY
# Processing JSON files:  26%|██▌       | 227/873 [20:56<1:04:20,  5.98s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=zzAn2o8sjAA
# Processing JSON files:  26%|██▌       | 228/873 [21:02<1:04:02,  5.96s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=0d4iA796hJg
# Processing JSON files:  26%|██▌       | 229/873 [21:08<1:03:03,  5.88s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=zi1vOQ3AZGg
# Processing JSON files:  26%|██▋       | 230/873 [21:16<1:10:58,  6.62s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ve-eFRtj7XA
# Processing JSON files:  26%|██▋       | 231/873 [21:27<1:23:09,  7.77s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=FRJZOfNSXxU
# Processing JSON files:  27%|██▋       | 232/873 [21:37<1:29:46,  8.40s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=EOHYIzh-wuo
# Processing JSON files:  27%|██▋       | 233/873 [21:47<1:34:43,  8.88s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=viofauPozO8
# Processing JSON files:  27%|██▋       | 234/873 [21:58<1:42:29,  9.62s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=8k8b76qvnpM
# Processing JSON files:  27%|██▋       | 235/873 [22:15<2:05:53, 11.84s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=olEryXVe_Rc
# Processing JSON files:  27%|██▋       | 236/873 [22:26<2:03:52, 11.67s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=iXTX0WJsaBs
# Processing JSON files:  27%|██▋       | 237/873 [22:33<1:46:45, 10.07s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=oP8GbeBnqBM
# Processing JSON files:  27%|██▋       | 238/873 [22:39<1:35:28,  9.02s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=wLLPOnCYaEI
# Processing JSON files:  27%|██▋       | 239/873 [22:45<1:25:32,  8.10s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=1z0RPS5ChWE
# Processing JSON files:  27%|██▋       | 240/873 [22:52<1:22:35,  7.83s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ENrm3molfZw
# Processing JSON files:  28%|██▊       | 241/873 [22:58<1:16:09,  7.23s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=PXtPv0jeElQ
# Processing JSON files:  28%|██▊       | 242/873 [23:05<1:13:41,  7.01s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=_f2U8H0EOJg
# Processing JSON files:  28%|██▊       | 243/873 [23:11<1:11:22,  6.80s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ZMDlmNoaq2Y
# Processing JSON files:  28%|██▊       | 244/873 [23:17<1:09:52,  6.67s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=RXMKnzguV9w
# Processing JSON files:  28%|██▊       | 245/873 [23:21<1:01:57,  5.92s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Dfk5fHBxAew
# Processing JSON files:  28%|██▊       | 246/873 [23:30<1:09:00,  6.60s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=PcJIvKEvVlI
# Processing JSON files:  28%|██▊       | 247/873 [23:36<1:08:16,  6.54s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=tJsRDIkVE8M
# Processing JSON files:  28%|██▊       | 248/873 [23:42<1:06:42,  6.40s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=sDcpEhZh5ME
# Processing JSON files:  29%|██▊       | 249/873 [23:45<56:41,  5.45s/it]  INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=zYUnqHAzYAA
# Processing JSON files:  29%|██▊       | 250/873 [23:51<57:30,  5.54s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=AoTYHwN_DvQ
# Processing JSON files:  29%|██▉       | 251/873 [23:55<52:49,  5.09s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=iZY8u7lFDwk
# Processing JSON files:  29%|██▉       | 252/873 [24:02<56:37,  5.47s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=efBnFILh8b4
# Processing JSON files:  29%|██▉       | 253/873 [24:07<56:32,  5.47s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=TCTZWAYVlq0
# Processing JSON files:  29%|██▉       | 254/873 [24:14<1:00:16,  5.84s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=riwL2bRd_h8
# Processing JSON files:  29%|██▉       | 255/873 [24:20<1:00:43,  5.90s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=5y7ddxoRGqU
# Processing JSON files:  29%|██▉       | 256/873 [24:26<1:01:56,  6.02s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=QG6LfBgNGM8
# Processing JSON files:  29%|██▉       | 257/873 [24:32<1:01:21,  5.98s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=JFj0wOh_Hrg
# Processing JSON files:  30%|██▉       | 258/873 [24:38<1:00:09,  5.87s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=-3pU3CHkG8c
# Processing JSON files:  30%|██▉       | 259/873 [24:42<56:49,  5.55s/it]  INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=oUyOoGjbR8o
# Processing JSON files:  30%|██▉       | 260/873 [24:49<1:00:18,  5.90s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=WxcsVP1DbHE
# Processing JSON files:  30%|██▉       | 261/873 [24:55<1:01:29,  6.03s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=oTfmbXrJOpU
# Processing JSON files:  30%|███       | 262/873 [25:01<1:01:03,  6.00s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=0G5Jt_yDN2I
# Processing JSON files:  30%|███       | 263/873 [25:07<59:18,  5.83s/it]  INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=_wEYbUfUYDo
# Processing JSON files:  30%|███       | 264/873 [25:12<58:52,  5.80s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Z07Qr8cz4c0
# Processing JSON files:  30%|███       | 265/873 [25:17<53:33,  5.28s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=PB0TqI0TIcE
# Processing JSON files:  30%|███       | 266/873 [25:23<55:56,  5.53s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=h8ucKndBnnE
# Processing JSON files:  31%|███       | 267/873 [25:29<56:48,  5.62s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=5MY1CEbJsv8
# Processing JSON files:  31%|███       | 268/873 [25:34<57:01,  5.65s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=HQAR3VnymYg
# Processing JSON files:  31%|███       | 269/873 [25:40<57:56,  5.76s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=cAJuNJoGhzg
# Processing JSON files:  31%|███       | 270/873 [25:46<58:37,  5.83s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=H4a8fj4-ur0
# Processing JSON files:  31%|███       | 271/873 [25:53<1:01:23,  6.12s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=dVYl-SnTVno
# Processing JSON files:  31%|███       | 272/873 [25:59<1:01:27,  6.14s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=PQAM1SumSHw
# Processing JSON files:  31%|███▏      | 273/873 [26:06<1:03:17,  6.33s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=95ImmSxip3I
# Processing JSON files:  31%|███▏      | 274/873 [26:12<1:02:03,  6.22s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=LisEYj6llL8
# Processing JSON files:  32%|███▏      | 275/873 [26:18<1:00:33,  6.08s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ahna3qjchXI
# Processing JSON files:  32%|███▏      | 276/873 [26:23<58:46,  5.91s/it]  INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=HqN_rk26InY
# Processing JSON files:  32%|███▏      | 277/873 [26:28<56:15,  5.66s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=X-XAmwLb2Ao
# Processing JSON files:  32%|███▏      | 278/873 [26:34<56:16,  5.67s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=W2evcLuqNOE
# Processing JSON files:  32%|███▏      | 279/873 [26:40<57:03,  5.76s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=zVZirOItl4o
# Processing JSON files:  32%|███▏      | 280/873 [26:46<56:31,  5.72s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=vfH4tEtYtsc
# Processing JSON files:  32%|███▏      | 281/873 [26:52<58:05,  5.89s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=wAJlQM4d8r0
# Processing JSON files:  32%|███▏      | 282/873 [26:58<57:31,  5.84s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=pl-J_fc0kYw
# Processing JSON files:  32%|███▏      | 283/873 [27:04<57:56,  5.89s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=aYddNi0tdbc
# Processing JSON files:  33%|███▎      | 284/873 [27:10<58:44,  5.98s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Y6N6OeVv3Tk
# Processing JSON files:  33%|███▎      | 285/873 [27:17<1:03:28,  6.48s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=15fUBJ4LwZA
# Processing JSON files:  33%|███▎      | 286/873 [27:24<1:02:41,  6.41s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=q6T26muRFiY
# Processing JSON files:  33%|███▎      | 287/873 [27:29<1:00:15,  6.17s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=umxw-i1AsrM
# Processing JSON files:  33%|███▎      | 288/873 [27:37<1:03:33,  6.52s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=IbJxf93gCco
# Processing JSON files:  33%|███▎      | 289/873 [27:42<58:40,  6.03s/it]  INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=fhwgi-tm6Tg
# Processing JSON files:  33%|███▎      | 290/873 [27:46<54:52,  5.65s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=nPAdsCvGfAE
# Processing JSON files:  33%|███▎      | 291/873 [27:52<54:06,  5.58s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=d4I3qgwsiG8
# Processing JSON files:  33%|███▎      | 292/873 [28:00<1:02:14,  6.43s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=X2pMfbn4mvU
# Processing JSON files:  34%|███▎      | 293/873 [28:06<1:00:22,  6.25s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=tQihZMGnjTM
# Processing JSON files:  34%|███▎      | 294/873 [28:13<1:03:31,  6.58s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=cNK70oHAzyM
# Processing JSON files:  34%|███▍      | 295/873 [28:19<59:55,  6.22s/it]  INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=9KDPlvqV1vk
# Processing JSON files:  34%|███▍      | 296/873 [28:25<59:28,  6.18s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=tholPg801bU
# Processing JSON files:  34%|███▍      | 297/873 [28:30<57:46,  6.02s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=rvNjkqakBa4
# Processing JSON files:  34%|███▍      | 298/873 [28:36<55:55,  5.83s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Q_40h8ixmS0
# Processing JSON files:  34%|███▍      | 299/873 [28:41<53:37,  5.60s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Mgoo-9QQwb0
# Processing JSON files:  34%|███▍      | 300/873 [28:47<53:43,  5.63s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=GdBOHxj7Ixw
# Processing JSON files:  34%|███▍      | 301/873 [28:53<55:15,  5.80s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=wCabnIWTGv4
# Processing JSON files:  35%|███▍      | 302/873 [28:59<56:03,  5.89s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=EnLo3Mwazd4
# Processing JSON files:  35%|███▍      | 303/873 [29:04<54:45,  5.76s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=i3xTOl8WQkI
# Processing JSON files:  35%|███▍      | 304/873 [29:10<55:10,  5.82s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=bQSbB-6jUHQ
# Processing JSON files:  35%|███▍      | 305/873 [29:16<54:28,  5.75s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=O_aGesWy-0c
# Processing JSON files:  35%|███▌      | 306/873 [29:24<1:01:29,  6.51s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=nLjZqANhaGw
# Processing JSON files:  35%|███▌      | 307/873 [29:30<59:16,  6.28s/it]  INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=JyQLcg-TJJI
# Processing JSON files:  35%|███▌      | 308/873 [29:34<53:19,  5.66s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=U90XHcBFRUc
# Processing JSON files:  35%|███▌      | 309/873 [29:40<54:43,  5.82s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=7Suurcu-Xl4
# Processing JSON files:  36%|███▌      | 310/873 [29:45<51:48,  5.52s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=pO7HRV9zKVg
# Processing JSON files:  36%|███▌      | 311/873 [29:51<52:49,  5.64s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=FHO3Xf9dHk4
# Processing JSON files:  36%|███▌      | 312/873 [29:57<53:40,  5.74s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=GUgVcLx3tKk
# Processing JSON files:  36%|███▌      | 313/873 [30:03<55:06,  5.90s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=v-TLpP1wv2o
# Processing JSON files:  36%|███▌      | 314/873 [30:09<55:06,  5.92s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=TQBG6m_IBJg
# Processing JSON files:  36%|███▌      | 315/873 [30:15<53:13,  5.72s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=mi2MQ_hkjaw
# Processing JSON files:  36%|███▌      | 316/873 [30:21<55:00,  5.93s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Aku5I0r7bPE
# Processing JSON files:  36%|███▋      | 317/873 [30:26<53:20,  5.76s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=qYRoUYv_RT8
# Processing JSON files:  36%|███▋      | 318/873 [30:32<53:03,  5.74s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=4rHmvJ17OtI
# Processing JSON files:  37%|███▋      | 319/873 [30:38<54:24,  5.89s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=bNm-Wi_VKWg
# Processing JSON files:  37%|███▋      | 320/873 [30:44<54:36,  5.92s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Zq3QrfncB2A
# Processing JSON files:  37%|███▋      | 321/873 [30:49<52:30,  5.71s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=0m45Ir6mWjM
# Processing JSON files:  37%|███▋      | 322/873 [30:55<53:05,  5.78s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=9BTyeGO6caE
# Processing JSON files:  37%|███▋      | 323/873 [31:01<53:11,  5.80s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=u-GHfRN6lyc
# Processing JSON files:  37%|███▋      | 324/873 [31:07<52:28,  5.73s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=tbID8vD8WIw
# Processing JSON files:  37%|███▋      | 325/873 [31:12<51:46,  5.67s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=i2kUGYgUpCk
# Processing JSON files:  37%|███▋      | 326/873 [31:18<52:45,  5.79s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Vo8R0Mfd0bA
# Processing JSON files:  37%|███▋      | 327/873 [31:24<53:21,  5.86s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=BGQ58ngJeDE
# Processing JSON files:  38%|███▊      | 328/873 [31:31<55:17,  6.09s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=D6l71u3IDC0
# Processing JSON files:  38%|███▊      | 329/873 [31:36<52:41,  5.81s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=EDATkp_JoU0
# Processing JSON files:  38%|███▊      | 330/873 [31:42<53:42,  5.93s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=0JyIfxtXmWs
# Processing JSON files:  38%|███▊      | 331/873 [31:48<53:58,  5.98s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=2DWl_J2hjbs
# Processing JSON files:  38%|███▊      | 332/873 [31:54<52:57,  5.87s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=213u3Z00rj8
# Processing JSON files:  38%|███▊      | 333/873 [32:01<55:08,  6.13s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=aBiYAa755dQ
# Processing JSON files:  38%|███▊      | 334/873 [32:07<54:14,  6.04s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=1rphBvWW2_Y
# Processing JSON files:  38%|███▊      | 335/873 [32:13<53:37,  5.98s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=AZMfiMYE8OM
# Processing JSON files:  38%|███▊      | 336/873 [32:17<50:06,  5.60s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=iyf56tbMue8
# Processing JSON files:  39%|███▊      | 337/873 [32:23<50:45,  5.68s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=S030qpzfbaQ
# Processing JSON files:  39%|███▊      | 338/873 [32:29<51:46,  5.81s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=m3PGR0jjgxI
# Processing JSON files:  39%|███▉      | 339/873 [32:34<49:33,  5.57s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=RvNRJBsCeHs
# Processing JSON files:  39%|███▉      | 340/873 [32:41<52:08,  5.87s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=xHbAf2ADXBE
# Processing JSON files:  39%|███▉      | 341/873 [32:47<52:37,  5.94s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=l6vK7KY0QQ4
# Processing JSON files:  39%|███▉      | 342/873 [32:52<50:01,  5.65s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=uZSwsL4hCBM
# Processing JSON files:  39%|███▉      | 343/873 [32:58<52:02,  5.89s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=htyAHlGNlqE
# Processing JSON files:  39%|███▉      | 344/873 [33:04<50:40,  5.75s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=dahf0_Bk7uo
# Processing JSON files:  40%|███▉      | 345/873 [33:09<49:43,  5.65s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=acLUdleteN4
# Processing JSON files:  40%|███▉      | 346/873 [33:15<49:52,  5.68s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=a0dO_yRPGhQ
# Processing JSON files:  40%|███▉      | 347/873 [33:21<51:58,  5.93s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=NJnQNhpQOOA
# Processing JSON files:  40%|███▉      | 348/873 [33:26<49:36,  5.67s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=QIXYR0AAZgY
# Processing JSON files:  40%|███▉      | 349/873 [33:32<48:31,  5.56s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=oonyhViozh4
# Processing JSON files:  40%|████      | 350/873 [33:36<45:21,  5.20s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=8VZWuhcO55I
# Processing JSON files:  40%|████      | 351/873 [33:44<51:08,  5.88s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=tSOr7_wyWDA
# Processing JSON files:  40%|████      | 352/873 [33:49<49:43,  5.73s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=txBHLRirY4o
# Processing JSON files:  40%|████      | 353/873 [33:54<48:12,  5.56s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=LTFnkHOPboY
# Processing JSON files:  41%|████      | 354/873 [34:00<48:42,  5.63s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Nl8kAluQOkY
# Processing JSON files:  41%|████      | 355/873 [34:06<50:03,  5.80s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=_zvsKiQKCG4
# Processing JSON files:  41%|████      | 356/873 [34:12<50:28,  5.86s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Ok6CBD7ycn0
# Processing JSON files:  41%|████      | 357/873 [34:18<50:12,  5.84s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=DrwFFqaIYJ0
# Processing JSON files:  41%|████      | 358/873 [34:24<50:06,  5.84s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=XyUWyThRFxw
# Processing JSON files:  41%|████      | 359/873 [34:28<46:34,  5.44s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=wwWGrFavoYs
# Processing JSON files:  41%|████      | 360/873 [34:34<46:00,  5.38s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=PCld83AkaoE
# Processing JSON files:  41%|████▏     | 361/873 [34:40<48:21,  5.67s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=GjpnR5uXS4k
# Processing JSON files:  41%|████▏     | 362/873 [34:46<49:40,  5.83s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=iAXb1zf6wic
# Processing JSON files:  42%|████▏     | 363/873 [34:52<50:04,  5.89s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=kntHqO2aBN0
# Processing JSON files:  42%|████▏     | 364/873 [34:58<49:27,  5.83s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=AJAOpV2_yT8
# Processing JSON files:  42%|████▏     | 365/873 [35:03<48:23,  5.72s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=j_5M0GLdzWc
# Processing JSON files:  42%|████▏     | 366/873 [35:07<44:22,  5.25s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=5GjJ3z0AmRs
# Processing JSON files:  42%|████▏     | 367/873 [35:13<44:30,  5.28s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=QVdE2cFHyq0
# Processing JSON files:  42%|████▏     | 368/873 [35:18<45:10,  5.37s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=UYAtXbzKin8
# Processing JSON files:  42%|████▏     | 369/873 [35:24<45:17,  5.39s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ebkgyXWRFXw
# Processing JSON files:  42%|████▏     | 370/873 [35:33<55:54,  6.67s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=jIrwVckMI8g
# Processing JSON files:  42%|████▏     | 371/873 [35:40<54:38,  6.53s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=lBgNACoBMSs
# Processing JSON files:  43%|████▎     | 372/873 [35:46<53:06,  6.36s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=pDhypT33yOM
# Processing JSON files:  43%|████▎     | 373/873 [35:51<50:19,  6.04s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=nzbCt5BcQIk
# Processing JSON files:  43%|████▎     | 374/873 [35:57<49:46,  5.98s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=5HePIHNLkLQ
# Processing JSON files:  43%|████▎     | 375/873 [36:02<48:01,  5.79s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=0iKQPjLI010
# Processing JSON files:  43%|████▎     | 376/873 [36:07<46:31,  5.62s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=DVLpI0VjQF0
# Processing JSON files:  43%|████▎     | 377/873 [36:13<46:51,  5.67s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Y9o3mjr4rFk
# Processing JSON files:  43%|████▎     | 378/873 [36:19<46:54,  5.69s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=RK7vQDr_Cq0
# Processing JSON files:  43%|████▎     | 379/873 [36:25<46:54,  5.70s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ROhrB3piUek
# Processing JSON files:  44%|████▎     | 380/873 [36:31<48:45,  5.93s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=urU_HEoU1gg
# Processing JSON files:  44%|████▎     | 381/873 [36:37<49:18,  6.01s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=XaQa9brFLUw
# Processing JSON files:  44%|████▍     | 382/873 [36:43<49:19,  6.03s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=0HZa3wZfoG4
# Processing JSON files:  44%|████▍     | 383/873 [36:49<48:07,  5.89s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=SOGldr7j71M
# Processing JSON files:  44%|████▍     | 384/873 [36:54<46:39,  5.72s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=dYNHe0fYXXs
# Processing JSON files:  44%|████▍     | 385/873 [37:00<46:46,  5.75s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ZKJpWLeyefs
# Processing JSON files:  44%|████▍     | 386/873 [37:05<46:00,  5.67s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=iqrH17ePJpU
# Processing JSON files:  44%|████▍     | 387/873 [37:11<46:05,  5.69s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=eX90--QIvp4
# Processing JSON files:  44%|████▍     | 388/873 [37:17<46:04,  5.70s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=mj4vAWGME1g
# Processing JSON files:  45%|████▍     | 389/873 [37:23<46:44,  5.79s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=qNcPXpmcldM
# Processing JSON files:  45%|████▍     | 390/873 [37:29<46:08,  5.73s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=R9U9njBBoxY
# Processing JSON files:  45%|████▍     | 391/873 [37:34<45:58,  5.72s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=dtggbYokGNM
# Processing JSON files:  45%|████▍     | 392/873 [37:40<46:39,  5.82s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=zD6FTlf0uHo
# Processing JSON files:  45%|████▌     | 393/873 [37:44<42:43,  5.34s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=8h9k5tBc9Ic
# Processing JSON files:  45%|████▌     | 394/873 [37:49<39:32,  4.95s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=kuTXGaSg0Pg
# Processing JSON files:  45%|████▌     | 395/873 [37:54<41:09,  5.17s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=yTx_z-AOamQ
# Processing JSON files:  45%|████▌     | 396/873 [38:00<42:39,  5.36s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=CymX2a-cZE4
# Processing JSON files:  45%|████▌     | 397/873 [38:06<43:34,  5.49s/it]ERROR: [youtube] TN9t7Lp84u4: Requested format is not available. Use --list-formats for a list of available formats
# ERROR:__main__:Attempt 1 failed for https://youtube.com/watch?v=TN9t7Lp84u4: ERROR: [youtube] TN9t7Lp84u4: Requested format is not available. Use --list-formats for a list of available formats
# INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=TN9t7Lp84u4
# Processing JSON files:  46%|████▌     | 398/873 [38:16<54:29,  6.88s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=j3BITM60cyY
# Processing JSON files:  46%|████▌     | 399/873 [38:21<49:42,  6.29s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=MyVmuWTRTXA
# Processing JSON files:  46%|████▌     | 400/873 [38:26<46:36,  5.91s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=-T_9LhKOwuc
# Processing JSON files:  46%|████▌     | 401/873 [38:30<43:03,  5.47s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=171F32Y7otE
# Processing JSON files:  46%|████▌     | 402/873 [38:36<42:32,  5.42s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=TmvxhlThOU4
# Processing JSON files:  46%|████▌     | 403/873 [38:41<41:12,  5.26s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=y2hqfUIYHvM
# Processing JSON files:  46%|████▋     | 404/873 [38:46<42:43,  5.47s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=KFjCuu-boyw
# Processing JSON files:  46%|████▋     | 405/873 [38:51<40:43,  5.22s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=nCpBbOOfCNk
# Processing JSON files:  47%|████▋     | 406/873 [38:57<42:06,  5.41s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=j8JySlBZ5SI
# Processing JSON files:  47%|████▋     | 407/873 [39:03<43:29,  5.60s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=p-sTCD_J530
# Processing JSON files:  47%|████▋     | 408/873 [39:09<43:38,  5.63s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=mkO39aewcf0
# Processing JSON files:  47%|████▋     | 409/873 [39:15<44:20,  5.73s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=k674VQhvDPo
# Processing JSON files:  47%|████▋     | 410/873 [39:20<44:20,  5.75s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Cxk2Bk2LWNw
# Processing JSON files:  47%|████▋     | 411/873 [39:27<45:16,  5.88s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=osKTolLRubc
# Processing JSON files:  47%|████▋     | 412/873 [39:32<43:51,  5.71s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=UVrl268vzeY
# Processing JSON files:  47%|████▋     | 413/873 [39:45<59:59,  7.82s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=LWTx34iyqn8
# Processing JSON files:  47%|████▋     | 414/873 [39:50<54:15,  7.09s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=yZ93hdzWzBk
# Processing JSON files:  48%|████▊     | 415/873 [39:55<50:02,  6.56s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=BPSHU456L1U
# Processing JSON files:  48%|████▊     | 416/873 [40:01<47:57,  6.30s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=_tIAL5eziNA
# Processing JSON files:  48%|████▊     | 417/873 [40:06<43:59,  5.79s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=pGvzwj1UJ8g
# Processing JSON files:  48%|████▊     | 418/873 [40:11<43:11,  5.69s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=-yP4nYfuTHE
# Processing JSON files:  48%|████▊     | 419/873 [40:17<43:23,  5.73s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=xh1sd5d3SPc
# Processing JSON files:  48%|████▊     | 420/873 [40:21<40:22,  5.35s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Y-ImrEyKWYk
# Processing JSON files:  48%|████▊     | 421/873 [40:27<39:49,  5.29s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=PInFIIZ4lNw
# Processing JSON files:  48%|████▊     | 422/873 [40:32<40:04,  5.33s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=kmMGeTsuM2Q
# Processing JSON files:  48%|████▊     | 423/873 [40:38<40:56,  5.46s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=D8RgVCetC-g
# Processing JSON files:  49%|████▊     | 424/873 [40:42<38:55,  5.20s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=UUr7uLYjkDE
# Processing JSON files:  49%|████▊     | 425/873 [40:48<40:26,  5.42s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=aSBfMk5FZlU
# Processing JSON files:  49%|████▉     | 426/873 [40:53<38:31,  5.17s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=tfTwi1neVkM
# Processing JSON files:  49%|████▉     | 427/873 [40:59<39:30,  5.31s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=qi_juJ0Lu18
# Processing JSON files:  49%|████▉     | 428/873 [41:04<39:46,  5.36s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=W5Jpc3FMFF0
# Processing JSON files:  49%|████▉     | 429/873 [41:09<39:40,  5.36s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=FjHxy7vQSNc
# Processing JSON files:  49%|████▉     | 430/873 [41:15<40:31,  5.49s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=HVe_Jjf_agI
# Processing JSON files:  49%|████▉     | 431/873 [41:21<40:40,  5.52s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=MIfibZBhqSY
# Processing JSON files:  49%|████▉     | 432/873 [41:27<41:36,  5.66s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=JFtVRf0qI10
# Processing JSON files:  50%|████▉     | 433/873 [41:32<40:59,  5.59s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=0L8hwHKbf-w
# Processing JSON files:  50%|████▉     | 434/873 [41:38<41:35,  5.69s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=bvAIo6br4l0
# Processing JSON files:  50%|████▉     | 435/873 [41:44<41:41,  5.71s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=SWOHxSIc4Sw
# Processing JSON files:  50%|████▉     | 436/873 [41:49<40:44,  5.59s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=n-T4J76fIZA
# Processing JSON files:  50%|█████     | 437/873 [41:56<42:18,  5.82s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=1xQVChdOA1U
# Processing JSON files:  50%|█████     | 438/873 [42:01<41:56,  5.78s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=QNjlCJOYMEY
# Processing JSON files:  50%|█████     | 439/873 [42:07<41:02,  5.67s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=4Qbu-E3hAaI
# Processing JSON files:  50%|█████     | 440/873 [42:11<37:04,  5.14s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=AJJHahQmdwg
# Processing JSON files:  51%|█████     | 441/873 [42:16<38:07,  5.29s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=C_HYkZoZanY
# Processing JSON files:  51%|█████     | 442/873 [42:22<38:17,  5.33s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Q-dpRfH7DiI
# Processing JSON files:  51%|█████     | 443/873 [42:29<41:34,  5.80s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=u0DFdf5iOqE
# Processing JSON files:  51%|█████     | 444/873 [42:34<40:36,  5.68s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=cgRU9QrX11s
# Processing JSON files:  51%|█████     | 445/873 [42:39<38:29,  5.40s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=8v7wcDw5_08
# Processing JSON files:  51%|█████     | 446/873 [42:43<36:22,  5.11s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=X7QFY0IsahY
# Processing JSON files:  51%|█████     | 447/873 [42:48<34:48,  4.90s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=mPCtbPYvWy0
# Processing JSON files:  51%|█████▏    | 448/873 [42:53<35:49,  5.06s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ohts95jErkw
# ...
# Processing JSON files:  89%|████████▉ | 778/873 [3:18:06<09:36,  6.07s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=49QGabZZdHI
# Processing JSON files:  89%|████████▉ | 779/873 [3:18:12<09:45,  6.22s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=fmE7xoSNjcU
# Processing JSON files:  89%|████████▉ | 780/873 [3:18:18<09:37,  6.21s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Tw8amdW5_kY
# Processing JSON files:  89%|████████▉ | 781/873 [3:18:23<08:48,  5.74s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=xhwVO3V9oi0
# Processing JSON files:  90%|████████▉ | 782/873 [3:18:29<08:57,  5.90s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=VFlp6KZL3uI
# Processing JSON files:  90%|████████▉ | 783/873 [3:18:35<08:57,  5.97s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=aW1gnfvMIag
# Processing JSON files:  90%|████████▉ | 784/873 [3:18:41<08:49,  5.94s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=wy7GtcNaVZU
# Processing JSON files:  90%|████████▉ | 785/873 [3:18:47<08:41,  5.93s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=gsR4rCct7RE
# Processing JSON files:  90%|█████████ | 786/873 [3:18:53<08:34,  5.92s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=zOJqflPAaxk
# Processing JSON files:  90%|█████████ | 787/873 [3:18:59<08:36,  6.00s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=TE9WlQX9O8Y
# Processing JSON files:  90%|█████████ | 788/873 [3:19:06<08:48,  6.22s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=IQ-dAO4DtLY
# Processing JSON files:  90%|█████████ | 789/873 [3:19:12<08:27,  6.04s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ZTrhZW1Mu44
# Processing JSON files:  90%|█████████ | 790/873 [3:19:17<08:16,  5.99s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=UBROYKS3SQE
# Processing JSON files:  91%|█████████ | 791/873 [3:19:24<08:22,  6.13s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=A1vwxmEFNFo
# Processing JSON files:  91%|█████████ | 792/873 [3:19:30<08:05,  5.99s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=3yXbJYJWOQY
# Processing JSON files:  91%|█████████ | 793/873 [3:19:35<07:50,  5.88s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=GXNXxVZiKwg
# Processing JSON files:  91%|█████████ | 794/873 [3:19:41<07:41,  5.84s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=B1caF2UNKYM
# Processing JSON files:  91%|█████████ | 795/873 [3:19:46<07:24,  5.70s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=uLKK8dCYLA0
# Processing JSON files:  91%|█████████ | 796/873 [3:19:52<07:15,  5.65s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=IWROho5sjF4
# Processing JSON files:  91%|█████████▏| 797/873 [3:19:58<07:19,  5.78s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=sOtGZ_7XXSA
# Processing JSON files:  91%|█████████▏| 798/873 [3:20:04<07:30,  6.01s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=RStRfBY39hU
# Processing JSON files:  92%|█████████▏| 799/873 [3:20:56<24:22, 19.76s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=QrckUWVBXM4
# Processing JSON files:  92%|█████████▏| 800/873 [3:21:55<38:07, 31.33s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=XWfzuNXMg0I
# Processing JSON files:  92%|█████████▏| 801/873 [3:22:57<48:47, 40.66s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ig2iI8azYTU
# Processing JSON files:  92%|█████████▏| 802/873 [3:23:58<55:08, 46.59s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=zOC3PjaOmpU
# Processing JSON files:  92%|█████████▏| 803/873 [3:24:50<56:19, 48.27s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=BNQ36v3g_38
# Processing JSON files:  92%|█████████▏| 804/873 [3:25:39<56:01, 48.71s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=zU7WeOX915I
# Processing JSON files:  92%|█████████▏| 805/873 [3:26:32<56:30, 49.85s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=6KXhreofgZo
# Processing JSON files:  92%|█████████▏| 806/873 [3:27:24<56:24, 50.51s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ZdRtPntRebI
# Processing JSON files:  92%|█████████▏| 807/873 [3:28:18<56:42, 51.55s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=IGK0b-SsBT8
# Processing JSON files:  93%|█████████▎| 808/873 [3:29:18<58:26, 53.95s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=A1YYKssUaSM
# Processing JSON files:  93%|█████████▎| 809/873 [3:30:14<58:11, 54.56s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=YCbabfKHttc
# Processing JSON files:  93%|█████████▎| 810/873 [3:31:14<58:59, 56.19s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=azvN9E0FCYQ
# Processing JSON files:  93%|█████████▎| 811/873 [3:31:45<50:22, 48.74s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=3SVVqwSgEts
# Processing JSON files:  93%|█████████▎| 812/873 [3:32:56<56:20, 55.41s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=hIYbICLJGHU
# Processing JSON files:  93%|█████████▎| 813/873 [3:33:53<55:57, 55.95s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=REoDm1UvwWQ
# Processing JSON files:  93%|█████████▎| 814/873 [3:34:46<54:03, 54.97s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=04XAyCRw-r4
# Processing JSON files:  93%|█████████▎| 815/873 [3:35:43<53:54, 55.77s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=dwz3Pu_5_Oo
# Processing JSON files:  93%|█████████▎| 816/873 [3:36:45<54:42, 57.60s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=-SYD0wQjPd4
# Processing JSON files:  94%|█████████▎| 817/873 [3:37:38<52:20, 56.08s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=0D9KW8W5Mdo
# Processing JSON files:  94%|█████████▎| 818/873 [3:38:18<46:59, 51.27s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=SUYmkr_-7BM
# Processing JSON files:  94%|█████████▍| 819/873 [3:38:52<41:28, 46.08s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=xZ-h9mdkAJQ
# Processing JSON files:  94%|█████████▍| 820/873 [3:39:11<33:38, 38.08s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=iKakpS0KqWw
# Processing JSON files:  94%|█████████▍| 821/873 [3:40:06<37:25, 43.17s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=EWX1ttKXD7M
# Processing JSON files:  94%|█████████▍| 822/873 [3:40:55<38:13, 44.98s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=iE0x-jNnoOo
# Processing JSON files:  94%|█████████▍| 823/873 [3:41:31<35:09, 42.20s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=-2NpDMgM_Mw
# Processing JSON files:  94%|█████████▍| 824/873 [3:42:17<35:20, 43.27s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=W2cRLfkrO48
# Processing JSON files:  95%|█████████▍| 825/873 [3:43:05<35:49, 44.78s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=T6SGHUssBlM
# Processing JSON files:  95%|█████████▍| 826/873 [3:44:24<43:04, 55.00s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=s0uarvHzsjs
# Processing JSON files:  95%|█████████▍| 827/873 [3:45:27<44:00, 57.39s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=liDOA4iMlbQ
# Processing JSON files:  95%|█████████▍| 828/873 [3:46:33<44:57, 59.95s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=TMmA7_vyyDk
# Processing JSON files:  95%|█████████▍| 829/873 [3:47:36<44:35, 60.80s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=UtSsdQOaQXo
# Processing JSON files:  95%|█████████▌| 830/873 [3:48:54<47:18, 66.00s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=fUmpbxxwUjI
# Processing JSON files:  95%|█████████▌| 831/873 [3:49:24<38:39, 55.24s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=I9lgobC7zW0
# Processing JSON files:  95%|█████████▌| 832/873 [3:50:17<37:21, 54.66s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=n9n7jZ0826M
# Processing JSON files:  95%|█████████▌| 833/873 [3:50:57<33:28, 50.21s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=1O85iaSp8mI
# Processing JSON files:  96%|█████████▌| 834/873 [3:51:42<31:37, 48.65s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=aBCOzE6WZOI
# Processing JSON files:  96%|█████████▌| 835/873 [3:52:29<30:27, 48.09s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=F0Fhw_0kp4g
# Processing JSON files:  96%|█████████▌| 836/873 [3:53:14<29:05, 47.17s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=iy5C9JmUtI4
# Processing JSON files:  96%|█████████▌| 837/873 [3:53:54<27:02, 45.08s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=Go8EU72klWA
# Processing JSON files:  96%|█████████▌| 838/873 [3:54:38<26:09, 44.84s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=QFYzmxM_I4Q
# Processing JSON files:  96%|█████████▌| 839/873 [3:55:29<26:25, 46.63s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=LQ2dPgNzKfQ
# Processing JSON files:  96%|█████████▌| 840/873 [3:56:25<27:05, 49.24s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=yiHDcwStnhM
# Processing JSON files:  96%|█████████▋| 841/873 [3:57:20<27:16, 51.15s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=hV4kwDQgdvw
# Processing JSON files:  96%|█████████▋| 842/873 [3:57:50<23:10, 44.85s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=qvaL7aPATFc
# Processing JSON files:  97%|█████████▋| 843/873 [3:58:44<23:39, 47.33s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=eZYnHmFDIro
# Processing JSON files:  97%|█████████▋| 844/873 [3:59:14<20:30, 42.43s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=gR0mTeteR04
# Processing JSON files:  97%|█████████▋| 845/873 [3:59:52<19:09, 41.05s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ezQ4LR54rnk
# Processing JSON files:  97%|█████████▋| 846/873 [4:00:41<19:28, 43.29s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=fVB_dRzhaN0
# Processing JSON files:  97%|█████████▋| 847/873 [4:01:29<19:22, 44.73s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ywjjXVohLNs
# Processing JSON files:  97%|█████████▋| 848/873 [4:02:07<17:46, 42.66s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=-imEtAqSvgY
# Processing JSON files:  97%|█████████▋| 849/873 [4:03:07<19:10, 47.94s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=3tBU3Pa2ys8
# Processing JSON files:  97%|█████████▋| 850/873 [4:04:01<19:05, 49.82s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=HFV6Jaspld8
# Processing JSON files:  97%|█████████▋| 851/873 [4:04:43<17:22, 47.39s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=IEZtrkG794I
# Processing JSON files:  98%|█████████▊| 852/873 [4:05:34<17:00, 48.57s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=B2vIR7EZnac
# Processing JSON files:  98%|█████████▊| 853/873 [4:06:15<15:24, 46.22s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=oOqxp67tCgQ
# Processing JSON files:  98%|█████████▊| 854/873 [4:06:55<14:04, 44.44s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=rNnSnWrITiY
# Processing JSON files:  98%|█████████▊| 855/873 [4:07:40<13:24, 44.67s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ooARL85vaYE
# Processing JSON files:  98%|█████████▊| 856/873 [4:08:25<12:40, 44.72s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=AbRc6CLY_M8
# Processing JSON files:  98%|█████████▊| 857/873 [4:09:16<12:26, 46.64s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=jEEh04VGLtw
# Processing JSON files:  98%|█████████▊| 858/873 [4:09:56<11:08, 44.54s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=2jFspBwznPw
# Processing JSON files:  98%|█████████▊| 859/873 [4:10:54<11:20, 48.64s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=lRUf6mjdd4s
# Processing JSON files:  99%|█████████▊| 860/873 [4:11:56<11:21, 52.43s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=kCB06CfmEY0
# Processing JSON files:  99%|█████████▊| 861/873 [4:12:22<08:54, 44.51s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=-FWnOaD6cUU
# Processing JSON files:  99%|█████████▊| 862/873 [4:13:16<08:42, 47.49s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=rENw-B7fsmQ
# Processing JSON files:  99%|█████████▉| 863/873 [4:14:10<08:14, 49.48s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=5ynpxihUKQQ
# Processing JSON files:  99%|█████████▉| 864/873 [4:15:09<07:49, 52.16s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=GXHddVXdLxE
# Processing JSON files:  99%|█████████▉| 865/873 [4:16:02<07:00, 52.61s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=bvzMTej15UM
# Processing JSON files:  99%|█████████▉| 866/873 [4:16:27<05:09, 44.27s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=95vQ4yGGRGU
# Processing JSON files:  99%|█████████▉| 867/873 [4:17:23<04:46, 47.69s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=ED034yanN_c
# Processing JSON files:  99%|█████████▉| 868/873 [4:18:14<04:03, 48.72s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=XeISyuQ-sDQ
# Processing JSON files: 100%|█████████▉| 869/873 [4:19:18<03:33, 53.30s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=iMBShv-CmyI
# Processing JSON files: 100%|█████████▉| 870/873 [4:20:28<02:55, 58.46s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=MGJ-x3Ky5UI
# Processing JSON files: 100%|█████████▉| 871/873 [4:21:28<01:57, 58.69s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=xNFsvysBHzU
# Processing JSON files: 100%|█████████▉| 872/873 [4:22:02<00:51, 51.35s/it]INFO:__main__:Successfully extracted FPS: 25 from https://youtube.com/watch?v=PnrBIfUOHQU
# Processing JSON files: 100%|██████████| 873/873 [4:23:03<00:00, 18.08s/it]
# ============================================================
# PROCESSING COMPLETE
# ============================================================
# Total files: 873
# Successfully processed: 692
# Already had FPS: 157
# Errors: 24
#
# Logs saved to:
# - Success log: fps_extraction_log.txt
# - Error log: fps_extraction_errors.txt
# (692, 24, 157)

# %%
# Utility function to check progress
def check_progress():
    """
    Check how many files already have FPS information
    """
    json_files = [f for f in os.listdir(MEDIA_INFO_DIR) if f.endswith('.json')]
    
    files_with_fps = 0
    files_without_fps = 0
    
    for filename in json_files:
        filepath = os.path.join(MEDIA_INFO_DIR, filename)
        try:
            with open(filepath, 'r', encoding='utf-8') as f:
                data = json.load(f)
            
            if 'fps' in data and data['fps'] is not None:
                files_with_fps += 1
            else:
                files_without_fps += 1
        except Exception as e:
            print(f"Error reading {filename}: {e}")
    
    print(f"Progress Check:")
    print(f"Total files: {len(json_files)}")
    print(f"Files with FPS: {files_with_fps}")
    print(f"Files without FPS: {files_without_fps}")
    print(f"Progress: {files_with_fps/len(json_files)*100:.1f}%")
    
    return files_with_fps, files_without_fps

# Check current progress
check_progress()
# Out:
# Progress Check:
# Total files: 873
# Files with FPS: 0
# Files without FPS: 873
# Progress: 0.0%
# (0, 873)
